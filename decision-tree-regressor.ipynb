CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
# 1  CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
# 2  CREAM, LIQUID SUGAR (SUGAR, WATER), SKIM MILK,...
# 3  CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
# 4  CREAM, SKIM MILK, WATER, LIQUID SUGAR (SUGAR, ...
#
# Reviews Dataset - First 5 rows:
#   brand   key          author        date  stars  \
# 0    bj  0_bj  Ilovebennjerry  2017-04-15      3
# 1    bj  0_bj   Sweettooth909  2020-01-05      5
# 2    bj  0_bj       LaTanga71  2018-04-26      3
# 3    bj  0_bj      chicago220  2018-01-14      5
# 4    bj  0_bj        Kassidyk  2020-07-24      1
#
#                                title  helpful_yes  helpful_no  \
# 0               Not enough brownies!         10.0         3.0
# 1       I’m OBSESSED with this pint!          3.0         0.0
# 2  My favorite...More Caramel Please          5.0         2.0
# 3                        Obsessed!!!         24.0         1.0
# 4              Worst Ice Cream Ever!          1.0         5.0
#
#                                                 text  taste  ingredients  \
# 0  Super good, don't get me wrong. But I came for...    NaN          NaN
# 1  I decided to try it out although I’m not a hug...    NaN          NaN
# 2  My caramel core begins to disappear about half...    NaN          NaN
# 3  Why are people complaining about the blonde br...    NaN          NaN
# 4  This ice cream is worst ice cream I’ve ever ta...    NaN          NaN
#
#    texture likes
# 0      NaN   NaN
# 1      NaN   NaN
# 2      NaN   NaN
# 3      NaN   NaN
# 4      NaN   NaN
#
# Products Columns:
# ['brand', 'key', 'name', 'subhead', 'description', 'rating', 'rating_count', 'ingredients']
#
# Reviews Columns:
# ['brand', 'key', 'author', 'date', 'stars', 'title', 'helpful_yes', 'helpful_no', 'text', 'taste', 'ingredients', 'texture', 'likes']
#
# [STEP 2] Exploring the data...
#
# Products Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         241 non-null    object
#  1   key           241 non-null    object
#  2   name          241 non-null    object
#  3   subhead       57 non-null     object
#  4   description   237 non-null    object
#  5   rating        241 non-null    float64
#  6   rating_count  241 non-null    int64
#  7   ingredients   241 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 15.2+ KB
# None
#
# Reviews Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21674 entries, 0 to 21673
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   brand        21674 non-null  object
#  1   key          21674 non-null  object
#  2   author       20873 non-null  object
#  3   date         21674 non-null  object
#  4   stars        21674 non-null  int64
#  5   title        16275 non-null  object
#  6   helpful_yes  21674 non-null  float64
#  7   helpful_no   21674 non-null  float64
#  8   text         21674 non-null  object
#  9   taste        4265 non-null   float64
#  10  ingredients  4265 non-null   float64
#  11  texture      4265 non-null   float64
#  12  likes        2295 non-null   object
# dtypes: float64(5), int64(1), object(7)
# memory usage: 2.1+ MB
# None
#
# Products Statistics:
#            rating  rating_count
# count  241.000000    241.000000
# mean     4.223237     90.016598
# std      0.620383    111.349449
# min      1.200000      2.000000
# 25%      4.000000     28.000000
# 50%      4.400000     59.000000
# 75%      4.700000    112.000000
# max      5.000000    983.000000
#
# Reviews Statistics:
#               stars   helpful_yes    helpful_no        taste  ingredients  \
# count  21674.000000  21674.000000  21674.000000  4265.000000  4265.000000
# mean       4.223955      1.364815      0.443019     4.234701     4.323798
# std        1.384121      8.234123      2.568762     1.401392     1.298888
# min        1.000000      0.000000      0.000000     1.000000     1.000000
# 25%        4.000000      0.000000      0.000000     4.000000     4.000000
# 50%        5.000000      0.000000      0.000000     5.000000     5.000000
# 75%        5.000000      1.000000      0.000000     5.000000     5.000000
# max        5.000000    421.000000    121.000000     5.000000     5.000000
#
#            texture
# count  4265.000000
# mean      4.284642
# std       1.363423
# min       1.000000
# 25%       4.000000
# 50%       5.000000
# 75%       5.000000
# max       5.000000
#
# [STEP 3] Preparing data for regression...
#
# Products columns: ['brand', 'key', 'name', 'subhead', 'description', 'rating', 'rating_count', 'ingredients']
# Reviews columns: ['brand', 'key', 'author', 'date', 'stars', 'title', 'helpful_yes', 'helpful_no', 'text', 'taste', 'ingredients', 'texture', 'likes']
# ✓ Merged dataset: 21674 rows
#
# Merged Dataset - First 5 rows:
#   brand_x   key          author        date  stars  \
# 0      bj  0_bj  Ilovebennjerry  2017-04-15      3
# 1      bj  0_bj   Sweettooth909  2020-01-05      5
# 2      bj  0_bj       LaTanga71  2018-04-26      3
# 3      bj  0_bj      chicago220  2018-01-14      5
# 4      bj  0_bj        Kassidyk  2020-07-24      1
#
#                                title  helpful_yes  helpful_no  \
# 0               Not enough brownies!         10.0         3.0
# 1       I’m OBSESSED with this pint!          3.0         0.0
# 2  My favorite...More Caramel Please          5.0         2.0
# 3                        Obsessed!!!         24.0         1.0
# 4              Worst Ice Cream Ever!          1.0         5.0
#
#                                                 text  taste  ingredients_x  \
# 0  Super good, don't get me wrong. But I came for...    NaN            NaN
# 1  I decided to try it out although I’m not a hug...    NaN            NaN
# 2  My caramel core begins to disappear about half...    NaN            NaN
# 3  Why are people complaining about the blonde br...    NaN            NaN
# 4  This ice cream is worst ice cream I’ve ever ta...    NaN            NaN
#
#    texture likes brand_y                 name  \
# 0      NaN   NaN      bj  Salted Caramel Core
# 1      NaN   NaN      bj  Salted Caramel Core
# 2      NaN   NaN      bj  Salted Caramel Core
# 3      NaN   NaN      bj  Salted Caramel Core
# 4      NaN   NaN      bj  Salted Caramel Core
#
#                                              subhead  \
# 0  Sweet Cream Ice Cream with Blonde Brownies & a...
# 1  Sweet Cream Ice Cream with Blonde Brownies & a...
# 2  Sweet Cream Ice Cream with Blonde Brownies & a...
# 3  Sweet Cream Ice Cream with Blonde Brownies & a...
# 4  Sweet Cream Ice Cream with Blonde Brownies & a...
#
#                                          description  rating  rating_count  \
# 0  Find your way to the ultimate ice cream experi...     3.7           208
# 1  Find your way to the ultimate ice cream experi...     3.7           208
# 2  Find your way to the ultimate ice cream experi...     3.7           208
# 3  Find your way to the ultimate ice cream experi...     3.7           208
# 4  Find your way to the ultimate ice cream experi...     3.7           208
#
#                                        ingredients_y
# 0  CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
# 1  CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
# 2  CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
# 3  CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
# 4  CREAM, SKIM MILK, LIQUID SUGAR (SUGAR, WATER),...
#
# Numeric columns: ['stars', 'helpful_yes', 'helpful_no', 'taste', 'ingredients_x', 'texture', 'rating', 'rating_count']
#
# ✓ After cleaning: 4265 rows
#
# Dataset preview:
#       rating  stars  helpful_yes  helpful_no  taste  ingredients_x  texture  \
# 7943     4.9      5         27.0         0.0    5.0            5.0      5.0
# 7944     4.9      5         10.0         0.0    5.0            5.0      5.0
# 7946     4.9      5          4.0         0.0    5.0            5.0      5.0
# 7947     4.9      5          8.0         0.0    5.0            5.0      5.0
# 7948     4.9      5          5.0         0.0    5.0            5.0      5.0
# 7949     4.9      5          5.0         0.0    5.0            5.0      5.0
# 7950     4.9      5          0.0         0.0    5.0            5.0      5.0
# 7951     4.9      5          2.0         0.0    5.0            5.0      5.0
# 7955     4.9      5          1.0         0.0    5.0            5.0      5.0
# 7956     4.9      5          0.0         0.0    5.0            5.0      5.0
#
#       rating_count
# 7943           168
# 7944           168
# 7946           168
# 7947           168
# 7948           168
# 7949           168
# 7950           168
# 7951           168
# 7955           168
# 7956           168
#
# ✓ Features shape: (4265, 7)
# ✓ Target shape: (4265,)
#
# Feature columns: ['stars', 'helpful_yes', 'helpful_no', 'taste', 'ingredients_x', 'texture', 'rating_count']
# Target column: rating
#
# [STEP 4] Splitting dataset...
# ✓ Training samples: 3412
# ✓ Test samples: 853
#
# [STEP 5] Training Decision Tree Regressor...
# ✓ Model trained successfully!
#
# [STEP 6] Making predictions...
#
# [STEP 7] Model Evaluation:
# ============================================================
# TRAINING SET PERFORMANCE:
#   - R² Score: 0.8599
#   - RMSE: 0.2552
#   - MAE: 0.1561
#
# TEST SET PERFORMANCE:
#   - R² Score: 0.8087
#   - RMSE: 0.2930
#   - MAE: 0.1831
#
# Overfitting Check:
#   - R² difference: 0.0512
#   - ✓ Model generalizes well
#
# [STEP 8] Creating visualizations...
# [STEP 9] Testing with sample predictions...
#
# Sample Predictions:
# ----------------------------------------------------------------------
# Sample 1:
#   stars: 1.00
#   helpful_yes: 2.00
#   helpful_no: 1.00
#   taste: 1.00
#   ingredients_x: 1.00
#   texture: 3.00
#   rating_count: 129.00
#   Predicted rating: 3.80
#   Actual rating: 3.50
#   Error: 0.30
# ----------------------------------------------------------------------
# Sample 2:
#   stars: 5.00
#   helpful_yes: 7.00
#   helpful_no: 3.00
#   taste: 5.00
#   ingredients_x: 5.00
#   texture: 5.00
#   rating_count: 13.00
#   Predicted rating: 4.19
#   Actual rating: 4.40
#   Error: 0.21
# ----------------------------------------------------------------------
# Sample 3:
#   stars: 5.00
#   helpful_yes: 0.00
#   helpful_no: 0.00
#   taste: 5.00
#   ingredients_x: 5.00
#   texture: 5.00
#   rating_count: 191.00
#   Predicted rating: 4.10
#   Actual rating: 4.10
#   Error: 0.00
# ----------------------------------------------------------------------
#
# [STEP 10] Saving model...
# ✓ Model saved as 'decision_tree_regressor_model.pkl'
# ✓ Feature names saved as 'feature_names.pkl'
# ✓ Target name saved as 'target_name.pkl'
#
# [STEP 11] Testing different max_depth values:
# ------------------------------------------------------------
# Depth=   3 | Train R²: 0.6213 | Test R²: 0.5413 | Gap: 0.0800
# Depth=   5 | Train R²: 0.6927 | Test R²: 0.6182 | Gap: 0.0745
# Depth=  10 | Train R²: 0.8662 | Test R²: 0.8133 | Gap: 0.0529
# Depth=  15 | Train R²: 0.9277 | Test R²: 0.8344 | Gap: 0.0932
# Depth=  20 | Train R²: 0.9317 | Test R²: 0.8353 | Gap: 0.0964
# Depth=None | Train R²: 0.9317 | Test R²: 0.8366 | Gap: 0.0951
#
# ============================================================
# ✓ TASK 3 COMPLETE!
# ============================================================
#
# Next Steps:
# 1. Download the .pkl files from Kaggle output
# 2. Create Streamlit app
# 3. Upload to GitHub
# 4. Deploy on Streamlit Cloud
